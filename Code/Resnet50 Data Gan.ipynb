# %%
import numpy as np
import os
from PIL import Image
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras_preprocessing.image import load_img
from keras_preprocessing import image
from keras_preprocessing.image import img_to_array
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 
import cv2
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import keras
from keras.models import Sequential, Model,load_model
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform

# %%
X = []
y = []

path="D:/data GAN"
for label in os.listdir(path):
    for directory in os.listdir(os.path.join(path,label)):
        image=load_img(os.path.join(os.path.join(path,label),directory))
        image = image.crop((121, 128, 890, 889))
        image = image.resize((150, 150))
        image=img_to_array(image)
        X.append(image)
        y.append(label) 
        #print(directory)

X = np.array(X)
y = np.array(y)

# %%
le = preprocessing.LabelEncoder()
le.fit(y)
y_encode = le.transform(y)

# %%
y_one_hot = tf.keras.utils.to_categorical(y_encode, num_classes=10)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.04, random_state=42)

# %%
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape=(224, 224, 3)):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')


    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
base_model = ResNet50(input_shape=(150,150, 3))

# %%
headModel = base_model.output
headModel = Flatten()(headModel)
headModel=Dense(256, activation='relu', name='fc1',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel=Dense(128, activation='relu', name='fc2',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel = Dense( 10,activation='softmax', name='fc3',kernel_initializer=glorot_uniform(seed=0))(headModel)

# %%
model = Model(inputs=base_model.input, outputs=headModel)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 156, 156, 3)  0          ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 75, 75, 64)   9472        ['zero_padding2d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 75, 75, 64)   256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 75, 75, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 37, 37, 64)   0           ['activation[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 37, 37, 64)   4160        ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 37, 37, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 37, 37, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 37, 37, 64)   36928       ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 37, 37, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 37, 37, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 37, 37, 256)  16640       ['activation_2[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 37, 37, 256)  16640       ['max_pooling2d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 37, 37, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 37, 37, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 37, 37, 256)  0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 37, 37, 256)  0           ['add[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 37, 37, 64)   16448       ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 37, 37, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 37, 37, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 37, 37, 64)   36928       ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 37, 37, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 37, 37, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 37, 37, 256)  16640       ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 37, 37, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 37, 37, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 37, 37, 256)  0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 37, 37, 64)   16448       ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 37, 37, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 37, 37, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 37, 37, 64)   36928       ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 37, 37, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 37, 37, 64)   0           ['bn2c_branch2b[0][0]']
#  res2c_branch2c (Conv2D)        (None, 37, 37, 256)  16640       ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 37, 37, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 37, 37, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 37, 37, 256)  0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 19, 19, 128)  32896       ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 19, 19, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 19, 19, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 19, 19, 128)  147584      ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 19, 19, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 19, 19, 128)  0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 19, 19, 512)  66048       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 19, 19, 512)  131584      ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 19, 19, 512)  2048       ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 19, 19, 512)  2048       ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 19, 19, 512)  0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 19, 19, 512)  0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 19, 19, 128)  65664       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 19, 19, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 19, 19, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 19, 19, 128)  147584      ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 19, 19, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 19, 19, 128)  0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 19, 19, 512)  66048       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 19, 19, 512)  2048       ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 19, 19, 512)  0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 19, 19, 512)  0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 19, 19, 128)  65664       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 19, 19, 128)  512        ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 19, 19, 128)  0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 19, 19, 128)  147584      ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 19, 19, 128)  512        ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 19, 19, 128)  0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 19, 19, 512)  66048       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 19, 19, 512)  2048       ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 19, 19, 512)  0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 19, 19, 512)  0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 19, 19, 128)  65664       ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 19, 19, 128)  512        ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 19, 19, 128)  0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 19, 19, 128)  147584      ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 19, 19, 128)  512        ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 19, 19, 128)  0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 19, 19, 512)  66048       ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 19, 19, 512)  2048       ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 19, 19, 512)  0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 19, 19, 512)  0           ['add_6[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 10, 10, 256)  131328      ['activation_21[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 10, 10, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_22[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 10, 10, 256)  0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  res4a_branch1 (Conv2D)         (None, 10, 10, 1024  525312      ['activation_21[0][0]']
#                                 )
#
#  bn4a_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch1 (BatchNormalizati  (None, 10, 10, 1024  4096       ['res4a_branch1[0][0]']
#  on)                            )
#
#  add_7 (Add)                    (None, 10, 10, 1024  0           ['bn4a_branch2c[0][0]',
#                                 )                                 'bn4a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 10, 10, 1024  0           ['add_7[0][0]']
#                                 )
#
#  res4b_branch2a (Conv2D)        (None, 10, 10, 256)  262400      ['activation_24[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 10, 10, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_25[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_26 (Activation)     (None, 10, 10, 256)  0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  bn4b_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4b_branch2c[0][0]']
#  ion)                           )
#
#  add_8 (Add)                    (None, 10, 10, 1024  0           ['bn4b_branch2c[0][0]',
#                                 )                                 'activation_24[0][0]']
#  activation_27 (Activation)     (None, 10, 10, 1024  0           ['add_8[0][0]']
#                                 )
#
#  res4c_branch2a (Conv2D)        (None, 10, 10, 256)  262400      ['activation_27[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_28 (Activation)     (None, 10, 10, 256)  0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_28[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 10, 10, 256)  0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  bn4c_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4c_branch2c[0][0]']
#  ion)                           )
#
#  add_9 (Add)                    (None, 10, 10, 1024  0           ['bn4c_branch2c[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 10, 10, 1024  0           ['add_9[0][0]']
#                                 )
#
#  res4d_branch2a (Conv2D)        (None, 10, 10, 256)  262400      ['activation_30[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 10, 10, 256)  0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_31[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_32 (Activation)     (None, 10, 10, 256)  0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  bn4d_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4d_branch2c[0][0]']
#  ion)                           )
#
#  add_10 (Add)                   (None, 10, 10, 1024  0           ['bn4d_branch2c[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 10, 10, 1024  0           ['add_10[0][0]']
#                                 )
#
#  res4e_branch2a (Conv2D)        (None, 10, 10, 256)  262400      ['activation_33[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 10, 10, 256)  0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_34[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 10, 10, 256)  0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  bn4e_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4e_branch2c[0][0]']
#  ion)                           )
#
#  add_11 (Add)                   (None, 10, 10, 1024  0           ['bn4e_branch2c[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 10, 10, 1024  0           ['add_11[0][0]']
#                                 )
#
#  res4f_branch2a (Conv2D)        (None, 10, 10, 256)  262400      ['activation_36[0][0]']
#  bn4f_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 10, 10, 256)  0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_37[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_38 (Activation)     (None, 10, 10, 256)  0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  bn4f_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4f_branch2c[0][0]']
#  ion)                           )
#
#  add_12 (Add)                   (None, 10, 10, 1024  0           ['bn4f_branch2c[0][0]',
#                                 )                                 'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 10, 10, 1024  0           ['add_12[0][0]']
#                                 )
#
#  res5a_branch2a (Conv2D)        (None, 5, 5, 512)    524800      ['activation_39[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_40 (Activation)     (None, 5, 5, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 5, 5, 512)    2359808     ['activation_40[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 5, 5, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 5, 5, 2048)   1050624     ['activation_41[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 5, 5, 2048)   2099200     ['activation_39[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 5, 5, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 5, 5, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 5, 5, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_42 (Activation)     (None, 5, 5, 2048)   0           ['add_13[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 5, 5, 512)    1049088     ['activation_42[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 5, 5, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 5, 5, 512)    2359808     ['activation_43[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_44 (Activation)     (None, 5, 5, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 5, 5, 2048)   1050624     ['activation_44[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 5, 5, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 5, 5, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 5, 5, 2048)   0           ['add_14[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 5, 5, 512)    1049088     ['activation_45[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_46 (Activation)     (None, 5, 5, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 5, 5, 512)    2359808     ['activation_46[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 5, 5, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 5, 5, 2048)   1050624     ['activation_47[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 5, 5, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 5, 5, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 5, 5, 2048)   0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 3, 3, 2048)  0           ['activation_48[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 18432)        0           ['average_pooling2d[0][0]']
#
#  fc1 (Dense)                    (None, 256)          4718848     ['flatten[0][0]']
#
#  fc2 (Dense)                    (None, 128)          32896       ['fc1[0][0]']
#
#  fc3 (Dense)                    (None, 10)           1290        ['fc2[0][0]']
#
# ==================================================================================================
# Total params: 28,340,746
# Trainable params: 28,287,626
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
base_model.load_weights("resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5")

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x000002CFF58F2160> False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x000002CFF58F2910> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CFF58EE850> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CFF58EE670> False
# <keras.layers.core.activation.Activation object at 0x000002CFF58F1A00> False
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000002CFF58F15B0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FC82130> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FC7B520> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FC7B490> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FC623A0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FC62580> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FC60EB0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FC57EE0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF800066A0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FC62E80> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF8000B700> False
# <keras.layers.merging.add.Add object at 0x000002CF8000B0A0> False
# <keras.layers.core.activation.Activation object at 0x000002CF8001BA60> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF8002F3A0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF800372B0> False
# <keras.layers.core.activation.Activation object at 0x000002CF800372E0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF80087310> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF80094B80> False
# <keras.layers.core.activation.Activation object at 0x000002CF80087670> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF8001B760> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF8001BF70> False
# <keras.layers.merging.add.Add object at 0x000002CF80087F40> False
# <keras.layers.core.activation.Activation object at 0x000002CF8000B9D0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FC6A8E0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FC60670> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FC57760> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF8009D610> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF800A4D60> False
# <keras.layers.core.activation.Activation object at 0x000002CF8009DE50> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF800B2070> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF800B2460> False
# <keras.layers.merging.add.Add object at 0x000002CF800BD2B0> False
# <keras.layers.core.activation.Activation object at 0x000002CF800BD4C0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF800C59D0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF800B2CA0> False
# <keras.layers.core.activation.Activation object at 0x000002CF800BDCA0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF800DA520> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF800DEA30> False
# <keras.layers.core.activation.Activation object at 0x000002CF800DEC10> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF800F7370> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF800FC700> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF800EFAF0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF800FC520> False
# <keras.layers.merging.add.Add object at 0x000002CF80103A00> False
# <keras.layers.core.activation.Activation object at 0x000002CF800D22B0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF800B7D60> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF800C5790> False
# <keras.layers.core.activation.Activation object at 0x000002CF800C55E0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FC6A430> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF8009FB50> False
# <keras.layers.core.activation.Activation object at 0x000002CF8009F640> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF8011A340> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF80111F10> False
# <keras.layers.merging.add.Add object at 0x000002CF80121400> False
# <keras.layers.core.activation.Activation object at 0x000002CF80121E80> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF80127CD0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF8012ECA0> False
# <keras.layers.core.activation.Activation object at 0x000002CF8012E640> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF80127BB0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF801D39A0> False
# <keras.layers.core.activation.Activation object at 0x000002CF8013ECD0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF801E2A30> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF801D3A90> False
# <keras.layers.merging.add.Add object at 0x000002CF801C8A30> False
# <keras.layers.core.activation.Activation object at 0x000002CF801E6BB0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF801EFDC0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF801FE0D0> False
# <keras.layers.core.activation.Activation object at 0x000002CF801E6670> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF801D3250> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF80127310> False
# <keras.layers.core.activation.Activation object at 0x000002CF80127B20> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF800C5520> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF800C5F70> False
# <keras.layers.merging.add.Add object at 0x000002CF80018460> False
# <keras.layers.core.activation.Activation object at 0x000002CF80203940> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF800A9130> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF80205A30> False
# <keras.layers.core.activation.Activation object at 0x000002CF80205A90> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF802137C0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF80227790> False
# <keras.layers.core.activation.Activation object at 0x000002CF80227220> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF80236220> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF8023B1C0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF802278B0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF8023B970> False
# <keras.layers.merging.add.Add object at 0x000002CF8023BCA0> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FDA2490> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FDAA370> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FDAC1C0> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FDBF0A0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FDB7C40> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF8023B610> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FDAAD60> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF8020EE80> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF80203250> False
# <keras.layers.merging.add.Add object at 0x000002CF8020E250> False
# <keras.layers.core.activation.Activation object at 0x000002CF8013E460> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FDC8520> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FD9A280> False
# <keras.layers.core.activation.Activation object at 0x000002CF801179A0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FDD0310> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FDDCD90> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FDD0940> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FDEB7C0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FDD0370> False
# <keras.layers.merging.add.Add object at 0x000002CF9FDE58E0> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FDF7310> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FE00220> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FE00C70> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE009A0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FE16310> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FE24E20> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE24FD0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FE314F0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FE31850> False
# <keras.layers.merging.add.Add object at 0x000002CF9FE08280> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE0D490> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FE31D30> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FDEE850> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE0D160> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FDD4130> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF8021A220> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FDBFAC0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FE43970> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FE39F40> False
# <keras.layers.merging.add.Add object at 0x000002CF9FE3D7F0> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE48AC0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FE4ED00> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FE55D90> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE55730> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FE4E160> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FE74A90> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE63F70> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FE87130> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FE74F40> False
# <keras.layers.merging.add.Add object at 0x000002CF9FE6E700> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE8C850> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CFF6D035E0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CFF6D133D0> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE8C1F0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CFF6D0C760> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FE6AEB0> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE6EFA0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FDAA9D0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CF9FDD4F40> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF8021D040> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CF9FDD46D0> False
# <keras.layers.merging.add.Add object at 0x000002CF9FE00670> False
# <keras.layers.core.activation.Activation object at 0x000002CFF6D1EFD0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CFF6D28D30> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CFF6D281F0> False
# <keras.layers.core.activation.Activation object at 0x000002CFF6D287F0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CFF6D36BB0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CFF6D30FA0> False
# <keras.layers.core.activation.Activation object at 0x000002CFF53710D0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CFF6D561C0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CFF58F2130> False
# <keras.layers.merging.add.Add object at 0x000002CFF52E1C70> False
# <keras.layers.core.activation.Activation object at 0x000002CFF53522E0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CFF6D5E9A0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CFF6D49B20> False
# <keras.layers.core.activation.Activation object at 0x000002CFF6D78F40> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CFF6D78760> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CFF6D81F70> False
# <keras.layers.core.activation.Activation object at 0x000002CFF6D50BB0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002CFF6D6E0A0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002CFF6D78D60> False
# <keras.layers.merging.add.Add object at 0x000002CFF6D69400> False
# <keras.layers.core.activation.Activation object at 0x000002CF9FE43100> False
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000002CF9FDAA5B0> False
# <keras.layers.reshaping.flatten.Flatten object at 0x000002CFF6D1ECD0> True
# <keras.layers.core.dense.Dense object at 0x000002CFF6D28C10> True
# <keras.layers.core.dense.Dense object at 0x000002CFF6DD8760> True
# <keras.layers.core.dense.Dense object at 0x000002CFF6DDDF70> True

# %%
model.compile(loss="categorical_crossentropy", optimizer='adam',metrics=["accuracy"])

# %%
history=model.fit(
    X_train,y_train,
    epochs=100,
    batch_size=100,
    validation_data=(X_test,y_test)
    )
# Out:
# Epoch 1/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.8450 - accuracy: 0.7444 - val_loss: 0.5382 - val_accuracy: 0.8192
# Epoch 2/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.3423 - accuracy: 0.8834 - val_loss: 0.5095 - val_accuracy: 0.8327
# Epoch 3/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.1713 - accuracy: 0.9428 - val_loss: 0.5821 - val_accuracy: 0.8375
# Epoch 4/100
# 250/250 [==============================] - 337s 1s/step - loss: 0.1019 - accuracy: 0.9664 - val_loss: 0.5605 - val_accuracy: 0.8490
# Epoch 5/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0715 - accuracy: 0.9763 - val_loss: 0.6636 - val_accuracy: 0.8442
# Epoch 6/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0541 - accuracy: 0.9829 - val_loss: 0.7331 - val_accuracy: 0.8519
# Epoch 7/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.0779 - accuracy: 0.9731 - val_loss: 0.7851 - val_accuracy: 0.8356
# Epoch 8/100
# 250/250 [==============================] - 334s 1s/step - loss: 0.0691 - accuracy: 0.9765 - val_loss: 0.7769 - val_accuracy: 0.8471
# Epoch 9/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.0609 - accuracy: 0.9794 - val_loss: 0.8470 - val_accuracy: 0.8471
# Epoch 10/100
# 250/250 [==============================] - 341s 1s/step - loss: 0.0536 - accuracy: 0.9814 - val_loss: 0.8978 - val_accuracy: 0.8365
# Epoch 11/100
# 250/250 [==============================] - 334s 1s/step - loss: 0.0420 - accuracy: 0.9846 - val_loss: 0.8502 - val_accuracy: 0.8442
# Epoch 12/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0515 - accuracy: 0.9838 - val_loss: 0.9949 - val_accuracy: 0.8471
# Epoch 13/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0541 - accuracy: 0.9818 - val_loss: 0.8899 - val_accuracy: 0.8577
# Epoch 14/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0473 - accuracy: 0.9840 - val_loss: 1.0976 - val_accuracy: 0.8394
# Epoch 15/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0284 - accuracy: 0.9911 - val_loss: 1.0067 - val_accuracy: 0.8538
# Epoch 16/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.0223 - accuracy: 0.9917 - val_loss: 1.0441 - val_accuracy: 0.8471
# Epoch 17/100
# 250/250 [==============================] - 337s 1s/step - loss: 0.0361 - accuracy: 0.9883 - val_loss: 1.3070 - val_accuracy: 0.8231
# Epoch 18/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0562 - accuracy: 0.9820 - val_loss: 0.9901 - val_accuracy: 0.8481
# Epoch 19/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0320 - accuracy: 0.9896 - val_loss: 1.0503 - val_accuracy: 0.8567
# Epoch 20/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0281 - accuracy: 0.9909 - val_loss: 1.1389 - val_accuracy: 0.8423
# Epoch 21/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.0498 - accuracy: 0.9845 - val_loss: 1.1443 - val_accuracy: 0.8394
# Epoch 22/100
# 250/250 [==============================] - 335s 1s/step - loss: 0.0340 - accuracy: 0.9891 - val_loss: 1.1337 - val_accuracy: 0.8490
# Epoch 23/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0352 - accuracy: 0.9891 - val_loss: 1.4130 - val_accuracy: 0.8394
# Epoch 24/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0367 - accuracy: 0.9889 - val_loss: 1.0554 - val_accuracy: 0.8462
# Epoch 25/100
# 250/250 [==============================] - 337s 1s/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 1.3584 - val_accuracy: 0.8423
# Epoch 26/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.0419 - accuracy: 0.9879 - val_loss: 1.1689 - val_accuracy: 0.8500
# Epoch 27/100
# 250/250 [==============================] - 335s 1s/step - loss: 0.0236 - accuracy: 0.9928 - val_loss: 1.2134 - val_accuracy: 0.8433
# Epoch 28/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 1.2656 - val_accuracy: 0.8538
# Epoch 29/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 1.4184 - val_accuracy: 0.8385
# Epoch 30/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 1.4041 - val_accuracy: 0.8481
# Epoch 31/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0426 - accuracy: 0.9871 - val_loss: 1.5615 - val_accuracy: 0.8317
# Epoch 32/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0509 - accuracy: 0.9846 - val_loss: 1.2656 - val_accuracy: 0.8500
# Epoch 33/100
# 250/250 [==============================] - 337s 1s/step - loss: 0.0167 - accuracy: 0.9947 - val_loss: 1.3853 - val_accuracy: 0.8442
# Epoch 34/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 1.5170 - val_accuracy: 0.8442
# Epoch 35/100
# 250/250 [==============================] - 335s 1s/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 1.3750 - val_accuracy: 0.8433
# Epoch 36/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0182 - accuracy: 0.9945 - val_loss: 1.4613 - val_accuracy: 0.8413
# Epoch 37/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0421 - accuracy: 0.9881 - val_loss: 1.4187 - val_accuracy: 0.8548
# Epoch 38/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0300 - accuracy: 0.9912 - val_loss: 1.4719 - val_accuracy: 0.8394
# Epoch 39/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 1.3928 - val_accuracy: 0.8423
# Epoch 40/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 1.3520 - val_accuracy: 0.8529
# Epoch 41/100
# 250/250 [==============================] - 337s 1s/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 1.3901 - val_accuracy: 0.8538
# Epoch 42/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 1.5271 - val_accuracy: 0.8452
# Epoch 43/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0498 - accuracy: 0.9869 - val_loss: 1.7165 - val_accuracy: 0.8288
# Epoch 44/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 1.4944 - val_accuracy: 0.8317
# Epoch 45/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0222 - accuracy: 0.9934 - val_loss: 1.4199 - val_accuracy: 0.8548
# Epoch 46/100
# 250/250 [==============================] - 334s 1s/step - loss: 0.0184 - accuracy: 0.9945 - val_loss: 1.3489 - val_accuracy: 0.8538
# Epoch 47/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 1.2797 - val_accuracy: 0.8663
# Epoch 48/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 1.3335 - val_accuracy: 0.8519
# Epoch 49/100
# 250/250 [==============================] - 341s 1s/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 1.6403 - val_accuracy: 0.8385
# Epoch 50/100
# 250/250 [==============================] - 341s 1s/step - loss: 0.0167 - accuracy: 0.9959 - val_loss: 1.6372 - val_accuracy: 0.8538
# Epoch 51/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0249 - accuracy: 0.9929 - val_loss: 1.4619 - val_accuracy: 0.8596
# Epoch 52/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.0238 - accuracy: 0.9939 - val_loss: 1.7017 - val_accuracy: 0.8375
# Epoch 53/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0190 - accuracy: 0.9948 - val_loss: 1.4016 - val_accuracy: 0.8567
# Epoch 54/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0246 - accuracy: 0.9927 - val_loss: 1.5040 - val_accuracy: 0.8375
# Epoch 55/100
# 250/250 [==============================] - 337s 1s/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 1.3925 - val_accuracy: 0.8519
# Epoch 56/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0114 - accuracy: 0.9971 - val_loss: 1.5182 - val_accuracy: 0.8423
# Epoch 57/100
# 250/250 [==============================] - 337s 1s/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 1.3668 - val_accuracy: 0.8462
# Epoch 58/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 1.4205 - val_accuracy: 0.8510
# Epoch 59/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 1.5954 - val_accuracy: 0.8519
# Epoch 60/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0322 - accuracy: 0.9908 - val_loss: 1.4775 - val_accuracy: 0.8442
# Epoch 61/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0213 - accuracy: 0.9945 - val_loss: 1.6037 - val_accuracy: 0.8510
# Epoch 62/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0210 - accuracy: 0.9944 - val_loss: 1.3424 - val_accuracy: 0.8587
# Epoch 63/100
# 250/250 [==============================] - 336s 1s/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 1.3872 - val_accuracy: 0.8635
# Epoch 64/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 1.5168 - val_accuracy: 0.8587
# Epoch 65/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 1.5428 - val_accuracy: 0.8558
# Epoch 66/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0117 - accuracy: 0.9970 - val_loss: 1.7319 - val_accuracy: 0.8269
# Epoch 67/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0306 - accuracy: 0.9917 - val_loss: 1.6410 - val_accuracy: 0.8490
# Epoch 68/100
# 250/250 [==============================] - 335s 1s/step - loss: 0.0093 - accuracy: 0.9966 - val_loss: 1.5141 - val_accuracy: 0.8471
# Epoch 69/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 1.7325 - val_accuracy: 0.8490
# Epoch 70/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 1.7522 - val_accuracy: 0.8404
# Epoch 71/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 1.7101 - val_accuracy: 0.8433
# Epoch 72/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 1.7987 - val_accuracy: 0.8385
# Epoch 73/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 1.5716 - val_accuracy: 0.8462
# Epoch 74/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 1.7027 - val_accuracy: 0.8529
# Epoch 75/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 2.0962 - val_accuracy: 0.8365
# Epoch 76/100
# 250/250 [==============================] - 341s 1s/step - loss: 0.0312 - accuracy: 0.9919 - val_loss: 1.9102 - val_accuracy: 0.8394
# Epoch 77/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0299 - accuracy: 0.9916 - val_loss: 1.7372 - val_accuracy: 0.8356
# Epoch 78/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0086 - accuracy: 0.9976 - val_loss: 1.5864 - val_accuracy: 0.8471
# Epoch 79/100
# 250/250 [==============================] - 338s 1s/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 1.6930 - val_accuracy: 0.8442
# Epoch 80/100
# 250/250 [==============================] - 335s 1s/step - loss: 0.0091 - accuracy: 0.9977 - val_loss: 1.7413 - val_accuracy: 0.8567
# Epoch 81/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 1.9064 - val_accuracy: 0.8442
# Epoch 82/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0171 - accuracy: 0.9956 - val_loss: 1.6626 - val_accuracy: 0.8538
# Epoch 83/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0121 - accuracy: 0.9968 - val_loss: 1.5285 - val_accuracy: 0.8692
# Epoch 84/100
# 250/250 [==============================] - 339s 1s/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 1.7322 - val_accuracy: 0.8558
# Epoch 85/100
# 250/250 [==============================] - 340s 1s/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 1.6273 - val_accuracy: 0.8577
# Epoch 86/100
# 250/250 [==============================] - 340s 1s/step - loss: 3.3267e-04 - accuracy: 1.0000 - val_loss: 1.5790 - val_accuracy: 0.8615
# Epoch 87/100
# 250/250 [==============================] - 338s 1s/step - loss: 1.3624e-04 - accuracy: 1.0000 - val_loss: 1.6033 - val_accuracy: 0.8625
# Epoch 88/100
# 250/250 [==============================] - 337s 1s/step - loss: 2.9320e-05 - accuracy: 1.0000 - val_loss: 1.5826 - val_accuracy: 0.8644
# Epoch 89/100
# 250/250 [==============================] - 344s 1s/step - loss: 1.9137e-05 - accuracy: 1.0000 - val_loss: 1.5899 - val_accuracy: 0.8625
# Epoch 90/100
# 250/250 [==============================] - 339s 1s/step - loss: 7.8953e-06 - accuracy: 1.0000 - val_loss: 1.5918 - val_accuracy: 0.8635
# Epoch 91/100
# 250/250 [==============================] - 337s 1s/step - loss: 6.7264e-06 - accuracy: 1.0000 - val_loss: 1.5954 - val_accuracy: 0.8625
# Epoch 92/100
# 250/250 [==============================] - 340s 1s/step - loss: 5.9133e-06 - accuracy: 1.0000 - val_loss: 1.5985 - val_accuracy: 0.8625
# Epoch 93/100
# 250/250 [==============================] - 340s 1s/step - loss: 5.2948e-06 - accuracy: 1.0000 - val_loss: 1.6023 - val_accuracy: 0.8625
# Epoch 94/100
# 250/250 [==============================] - 338s 1s/step - loss: 4.7597e-06 - accuracy: 1.0000 - val_loss: 1.6058 - val_accuracy: 0.8635
# Epoch 95/100
# 250/250 [==============================] - 339s 1s/step - loss: 4.3052e-06 - accuracy: 1.0000 - val_loss: 1.6099 - val_accuracy: 0.8654
# Epoch 96/100
# 250/250 [==============================] - 337s 1s/step - loss: 3.8946e-06 - accuracy: 1.0000 - val_loss: 1.6144 - val_accuracy: 0.8654
# Epoch 97/100
# 250/250 [==============================] - 336s 1s/step - loss: 3.5248e-06 - accuracy: 1.0000 - val_loss: 1.6180 - val_accuracy: 0.8654
# Epoch 98/100
# 250/250 [==============================] - 340s 1s/step - loss: 3.1993e-06 - accuracy: 1.0000 - val_loss: 1.6222 - val_accuracy: 0.8644
# Epoch 99/100
# 250/250 [==============================] - 340s 1s/step - loss: 2.9083e-06 - accuracy: 1.0000 - val_loss: 1.6268 - val_accuracy: 0.8644
# Epoch 100/100
# 250/250 [==============================] - 339s 1s/step - loss: 2.6417e-06 - accuracy: 1.0000 - val_loss: 1.6319 - val_accuracy: 0.8663

# %%
from sklearn.metrics import confusion_matrix

y_pred=model.predict(X_test)
y_pred_one_hot=np.argmax(y_pred,axis=1)
y_test_one_hot=np.argmax(y_test,axis=1)
confusion_mat=confusion_matrix(y_test_one_hot, y_pred_one_hot)
print(confusion_mat)
# Out:
# 33/33 [==============================] - 15s 444ms/step
# [[ 47   8   1   0   0   0   0   1   0   5]
#  [  5 162   5   1   0   7   6   0   3   2]
#  [  1   6  99   0   0   0   0   0   0   0]
#  [  1   2   0  60   0   0   3   0   1   1]
#  [  0   2   0   0  89   0   0   0   2   2]
#  [  0   8   0   0   0  93   2   1   3   3]
#  [  0   2   3   3   0   2  60   3   1   0]
#  [  0   3   2   2   0   0   4  58   4   1]
#  [  3   3   0   0   3   1   3   1 180   1]
#  [  2   2   1   0   1   2   0   0   4  53]]

# %%
report= classification_report(y_test_one_hot,y_pred_one_hot)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78        62
#            1       0.82      0.85      0.83       191
#            2       0.89      0.93      0.91       106
#            3       0.91      0.88      0.90        68
#            4       0.96      0.94      0.95        95
#            5       0.89      0.85      0.87       110
#            6       0.77      0.81      0.79        74
#            7       0.91      0.78      0.84        74
#            8       0.91      0.92      0.92       195
#            9       0.78      0.82      0.80        65
#
#     accuracy                           0.87      1040
#    macro avg       0.86      0.85      0.86      1040
# weighted avg       0.87      0.87      0.87      1040

# %%
import matplotlib.pyplot as plt                                                   #Mengimpor modul matplotlib
acc = history.history['accuracy']                                                 #Nilai akurasi training
val_acc = history.history['val_accuracy']                                         #Nilai akurasi validasi
loss = history.history['loss']                                                    #Nilai loss training
val_loss = history.history['val_loss']                                            #Nilai loss validasi

epochs = range(len(acc))                                                          #Jumlah epoch

plt.plot(epochs, acc, 'r', label='Akurasi Training ')                             #Plot nilai akurasi training                     
plt.plot(epochs, val_acc, 'b', label='Akurasi Validasi')                          #Plot nilai akurasi validasi
plt.title('Akurasi Training dan Validasi')                                        #Menamai gambar
plt.legend(loc=0)                                                                 #Menampilkan legenda
plt.figure()                                                                      
plt.show()
