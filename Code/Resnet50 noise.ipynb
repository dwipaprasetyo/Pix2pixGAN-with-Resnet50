# %%
import numpy as np
import os
from PIL import Image
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras_preprocessing.image import load_img
from keras_preprocessing import image
from keras_preprocessing.image import img_to_array
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 
import cv2
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import keras
from keras.models import Sequential, Model,load_model
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform
from tqdm import tqdm
from skimage.io import imread, imshow, imsave
from skimage.transform import resize
import math
import random

# %%
def preprocess(array):
    array = array.astype("float32")/255
    return array

# %%
def noise_speckle(image, seed=None, clip=True):
    # Detect if a signed image was input
    if image.min() < 0:
        low_clip = -1.0
    else:
        low_clip = 0.0

    image = preprocess(image)
    rng = np.random.default_rng(seed)
    noise = rng.normal(0, 0.1 ** 0.5, image.shape)
    out = image + image * noise

    # Clip back to original range, if necessary
    if clip:
        out = np.clip(out, low_clip, 1.0)

    out = out * 255
    out = out.astype("uint8")
    return out

# %%
path="D:/raw-img"

# %%
import os
image_list=[]
n=0
for path, subdirs, files in os.walk(path):
    for name in files:  
        filename=path+'/'+name
        filename=filename.replace('\\','/')
        image_list.append(filename)
        n=n+1

# %%
X = []
y = []
for i in tqdm(range(0,n)):
    filename = image_list[i]
    Images = imread(filename)
    Images = resize(Images, (150,150,3))
    Images = Images * 255
    Images = Images.astype("uint8")
    Images = noise_speckle(Images)
    imsave((filename+'__'+'speckle'+'_noise_.JPEG'), Images)
    # extracting class name from filename
    class_name = filename.split('/')[-2]
    # appending image and label to X and y lists
    X.append(Images)
    y.append(class_name)
    
# converting X and y to numpy arrays
X = np.array(X)
y = np.array(y)
# Out:
#  36%|███████████████████████████▌                                                 | 9354/26179 [02:33<10:58, 25.56it/s]C:\Users\smart pc\AppData\Local\Temp\ipykernel_12024\2415502073.py:10: UserWarning: D:/Folder dwipa/raw-img noise/farfalla/eb35b30729f1073ed1584d05fb1d4e9fe777ead218ac104497f5c97faeebb5bb_640.png__speckle_noise_.JPEG is a low contrast image
#   imsave((filename+'__'+'speckle'+'_noise_.JPEG'), Images)
# 100%|████████████████████████████████████████████████████████████████████████████| 26179/26179 [11:05<00:00, 39.31it/s]

# %%
le = preprocessing.LabelEncoder()
le.fit(y)
y_encode = le.transform(y)

# %%
y_one_hot = tf.keras.utils.to_categorical(y_encode, num_classes=10)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.04, random_state=42)

# %%
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape=(224, 224, 3)):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')


    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
base_model = ResNet50(input_shape=(150,150, 3))

# %%
headModel = base_model.output
headModel = Flatten()(headModel)
headModel=Dense(256, activation='relu', name='fc1',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel=Dense(128, activation='relu', name='fc2',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel = Dense( 10,activation='softmax', name='fc3',kernel_initializer=glorot_uniform(seed=0))(headModel)

# %%
model = Model(inputs=base_model.input, outputs=headModel)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 156, 156, 3)  0          ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 75, 75, 64)   9472        ['zero_padding2d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 75, 75, 64)   256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 75, 75, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 37, 37, 64)   0           ['activation[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 37, 37, 64)   4160        ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 37, 37, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 37, 37, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 37, 37, 64)   36928       ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 37, 37, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 37, 37, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 37, 37, 256)  16640       ['activation_2[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 37, 37, 256)  16640       ['max_pooling2d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 37, 37, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 37, 37, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 37, 37, 256)  0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 37, 37, 256)  0           ['add[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 37, 37, 64)   16448       ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 37, 37, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 37, 37, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 37, 37, 64)   36928       ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 37, 37, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 37, 37, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 37, 37, 256)  16640       ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 37, 37, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 37, 37, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 37, 37, 256)  0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 37, 37, 64)   16448       ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 37, 37, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 37, 37, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 37, 37, 64)   36928       ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 37, 37, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 37, 37, 64)   0           ['bn2c_branch2b[0][0]']
#  res2c_branch2c (Conv2D)        (None, 37, 37, 256)  16640       ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 37, 37, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 37, 37, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 37, 37, 256)  0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 19, 19, 128)  32896       ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 19, 19, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 19, 19, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 19, 19, 128)  147584      ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 19, 19, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 19, 19, 128)  0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 19, 19, 512)  66048       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 19, 19, 512)  131584      ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 19, 19, 512)  2048       ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 19, 19, 512)  2048       ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 19, 19, 512)  0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 19, 19, 512)  0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 19, 19, 128)  65664       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 19, 19, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 19, 19, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 19, 19, 128)  147584      ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 19, 19, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 19, 19, 128)  0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 19, 19, 512)  66048       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 19, 19, 512)  2048       ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 19, 19, 512)  0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 19, 19, 512)  0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 19, 19, 128)  65664       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 19, 19, 128)  512        ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 19, 19, 128)  0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 19, 19, 128)  147584      ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 19, 19, 128)  512        ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 19, 19, 128)  0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 19, 19, 512)  66048       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 19, 19, 512)  2048       ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 19, 19, 512)  0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 19, 19, 512)  0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 19, 19, 128)  65664       ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 19, 19, 128)  512        ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 19, 19, 128)  0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 19, 19, 128)  147584      ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 19, 19, 128)  512        ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 19, 19, 128)  0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 19, 19, 512)  66048       ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 19, 19, 512)  2048       ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 19, 19, 512)  0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 19, 19, 512)  0           ['add_6[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 10, 10, 256)  131328      ['activation_21[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 10, 10, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_22[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 10, 10, 256)  0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  res4a_branch1 (Conv2D)         (None, 10, 10, 1024  525312      ['activation_21[0][0]']
#                                 )
#
#  bn4a_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch1 (BatchNormalizati  (None, 10, 10, 1024  4096       ['res4a_branch1[0][0]']
#  on)                            )
#
#  add_7 (Add)                    (None, 10, 10, 1024  0           ['bn4a_branch2c[0][0]',
#                                 )                                 'bn4a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 10, 10, 1024  0           ['add_7[0][0]']
#                                 )
#
#  res4b_branch2a (Conv2D)        (None, 10, 10, 256)  262400      ['activation_24[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 10, 10, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_25[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_26 (Activation)     (None, 10, 10, 256)  0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  bn4b_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4b_branch2c[0][0]']
#  ion)                           )
#
#  add_8 (Add)                    (None, 10, 10, 1024  0           ['bn4b_branch2c[0][0]',
#                                 )                                 'activation_24[0][0]']
#  activation_27 (Activation)     (None, 10, 10, 1024  0           ['add_8[0][0]']
#                                 )
#
#  res4c_branch2a (Conv2D)        (None, 10, 10, 256)  262400      ['activation_27[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_28 (Activation)     (None, 10, 10, 256)  0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_28[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 10, 10, 256)  0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  bn4c_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4c_branch2c[0][0]']
#  ion)                           )
#
#  add_9 (Add)                    (None, 10, 10, 1024  0           ['bn4c_branch2c[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 10, 10, 1024  0           ['add_9[0][0]']
#                                 )
#
#  res4d_branch2a (Conv2D)        (None, 10, 10, 256)  262400      ['activation_30[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 10, 10, 256)  0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_31[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_32 (Activation)     (None, 10, 10, 256)  0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  bn4d_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4d_branch2c[0][0]']
#  ion)                           )
#
#  add_10 (Add)                   (None, 10, 10, 1024  0           ['bn4d_branch2c[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 10, 10, 1024  0           ['add_10[0][0]']
#                                 )
#
#  res4e_branch2a (Conv2D)        (None, 10, 10, 256)  262400      ['activation_33[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 10, 10, 256)  0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_34[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 10, 10, 256)  0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  bn4e_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4e_branch2c[0][0]']
#  ion)                           )
#
#  add_11 (Add)                   (None, 10, 10, 1024  0           ['bn4e_branch2c[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 10, 10, 1024  0           ['add_11[0][0]']
#                                 )
#
#  res4f_branch2a (Conv2D)        (None, 10, 10, 256)  262400      ['activation_36[0][0]']
#  bn4f_branch2a (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 10, 10, 256)  0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 10, 10, 256)  590080      ['activation_37[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 10, 10, 256)  1024       ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_38 (Activation)     (None, 10, 10, 256)  0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 10, 10, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  bn4f_branch2c (BatchNormalizat  (None, 10, 10, 1024  4096       ['res4f_branch2c[0][0]']
#  ion)                           )
#
#  add_12 (Add)                   (None, 10, 10, 1024  0           ['bn4f_branch2c[0][0]',
#                                 )                                 'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 10, 10, 1024  0           ['add_12[0][0]']
#                                 )
#
#  res5a_branch2a (Conv2D)        (None, 5, 5, 512)    524800      ['activation_39[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_40 (Activation)     (None, 5, 5, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 5, 5, 512)    2359808     ['activation_40[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 5, 5, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 5, 5, 2048)   1050624     ['activation_41[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 5, 5, 2048)   2099200     ['activation_39[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 5, 5, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 5, 5, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 5, 5, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_42 (Activation)     (None, 5, 5, 2048)   0           ['add_13[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 5, 5, 512)    1049088     ['activation_42[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 5, 5, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 5, 5, 512)    2359808     ['activation_43[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_44 (Activation)     (None, 5, 5, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 5, 5, 2048)   1050624     ['activation_44[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 5, 5, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 5, 5, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 5, 5, 2048)   0           ['add_14[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 5, 5, 512)    1049088     ['activation_45[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_46 (Activation)     (None, 5, 5, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 5, 5, 512)    2359808     ['activation_46[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 5, 5, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 5, 5, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 5, 5, 2048)   1050624     ['activation_47[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 5, 5, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 5, 5, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 5, 5, 2048)   0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 3, 3, 2048)  0           ['activation_48[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 18432)        0           ['average_pooling2d[0][0]']
#
#  fc1 (Dense)                    (None, 256)          4718848     ['flatten[0][0]']
#
#  fc2 (Dense)                    (None, 128)          32896       ['fc1[0][0]']
#
#  fc3 (Dense)                    (None, 10)           1290        ['fc2[0][0]']
#
# ==================================================================================================
# Total params: 28,340,746
# Trainable params: 28,287,626
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
base_model.load_weights("resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5")

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x0000013B0FD77790> False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x0000013B6B391F40> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B6B388400> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B6B3884C0> False
# <keras.layers.core.activation.Activation object at 0x0000013B0FE1D790> False
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x0000013B687796D0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B633CAF40> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B0FD74970> False
# <keras.layers.core.activation.Activation object at 0x0000013B686FA790> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B379D6F40> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B633CA850> False
# <keras.layers.core.activation.Activation object at 0x0000013B379DA3A0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B359C6130> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B359DCDC0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B379DD520> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B359E4C70> False
# <keras.layers.merging.add.Add object at 0x0000013B359E4790> False
# <keras.layers.core.activation.Activation object at 0x0000013B6873B760> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56041640> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B5601C8B0> False
# <keras.layers.core.activation.Activation object at 0x0000013B5601CB80> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B10F1B640> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B5601C820> False
# <keras.layers.core.activation.Activation object at 0x0000013B56039B80> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B5601C400> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B10F1B970> False
# <keras.layers.merging.add.Add object at 0x0000013B10F1B3D0> False
# <keras.layers.core.activation.Activation object at 0x0000013B10F1B2B0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B736DB700> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B359C6340> False
# <keras.layers.core.activation.Activation object at 0x0000013B379FBB20> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B63373F70> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B10EF6910> False
# <keras.layers.core.activation.Activation object at 0x0000013B634134F0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B63413250> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B63413FA0> False
# <keras.layers.merging.add.Add object at 0x0000013B634050A0> False
# <keras.layers.core.activation.Activation object at 0x0000013B63426E80> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B736D2CD0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B63413700> False
# <keras.layers.core.activation.Activation object at 0x0000013B63370340> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B633F0E20> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B736ECC70> False
# <keras.layers.core.activation.Activation object at 0x0000013B379DA610> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B560307C0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B0FE6D160> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B379F2C70> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B10F2F130> False
# <keras.layers.merging.add.Add object at 0x0000013B0FE6D670> False
# <keras.layers.core.activation.Activation object at 0x0000013B35999040> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B35999580> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B10EA0700> False
# <keras.layers.core.activation.Activation object at 0x0000013B10EA0CD0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B35977F70> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B359771C0> False
# <keras.layers.core.activation.Activation object at 0x0000013B10EA0E80> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B10F28970> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B10EA39A0> False
# <keras.layers.merging.add.Add object at 0x0000013B63385D00> False
# <keras.layers.core.activation.Activation object at 0x0000013B0FE7FFA0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B10F10610> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B10F28250> False
# <keras.layers.core.activation.Activation object at 0x0000013B379DD340> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B359A6EE0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B736D2280> False
# <keras.layers.core.activation.Activation object at 0x0000013B4A730520> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B4A730F70> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B4A7303D0> False
# <keras.layers.merging.add.Add object at 0x0000013B4A74C430> False
# <keras.layers.core.activation.Activation object at 0x0000013B634264C0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B633703D0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B4A730730> False
# <keras.layers.core.activation.Activation object at 0x0000013B4A6DC280> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56039310> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B35995CA0> False
# <keras.layers.core.activation.Activation object at 0x0000013B736DB730> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B633F0D60> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B379F2280> False
# <keras.layers.merging.add.Add object at 0x0000013B0FE4C190> False
# <keras.layers.core.activation.Activation object at 0x0000013B4A6EB400> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B55FE9E50> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B10EC0910> False
# <keras.layers.core.activation.Activation object at 0x0000013B7767E640> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B77653DF0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B77653AF0> False
# <keras.layers.core.activation.Activation object at 0x0000013B776530A0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B55FD2160> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B10EA3700> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B7766AD00> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B55FE4520> False
# <keras.layers.merging.add.Add object at 0x0000013B10EC0640> False
# <keras.layers.core.activation.Activation object at 0x0000013B4A766730> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B7766A7F0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B35999370> False
# <keras.layers.core.activation.Activation object at 0x0000013B379D60D0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B3591BD90> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B359958E0> False
# <keras.layers.core.activation.Activation object at 0x0000013B359018B0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B4A776220> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B4A776640> False
# <keras.layers.merging.add.Add object at 0x0000013B4A707F70> False
# <keras.layers.core.activation.Activation object at 0x0000013B4A7128B0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B3591BA30> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B4A77DD00> False
# <keras.layers.core.activation.Activation object at 0x0000013B4A77DE80> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B4A712460> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B4A6F3730> False
# <keras.layers.core.activation.Activation object at 0x0000013B358FE3A0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B55FE4820> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B633998E0> False
# <keras.layers.merging.add.Add object at 0x0000013B10EA31F0> False
# <keras.layers.core.activation.Activation object at 0x0000013B4A79AA90> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B4A7A22E0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B55FD2FD0> False
# <keras.layers.core.activation.Activation object at 0x0000013B560A7880> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B5609DB50> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B560B7CA0> False
# <keras.layers.core.activation.Activation object at 0x0000013B560AF850> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B560C05B0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B5609DFD0> False
# <keras.layers.merging.add.Add object at 0x0000013B560B74C0> False
# <keras.layers.core.activation.Activation object at 0x0000013B4A783640> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B359A62E0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B560CD3D0> False
# <keras.layers.core.activation.Activation object at 0x0000013B4A6BFD30> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B736ED310> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B0FE531F0> False
# <keras.layers.core.activation.Activation object at 0x0000013B35901BE0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56A220D0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B4A77D2E0> False
# <keras.layers.merging.add.Add object at 0x0000013B56A55640> False
# <keras.layers.core.activation.Activation object at 0x0000013B56A4F3A0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56A5CA60> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B56A55040> False
# <keras.layers.core.activation.Activation object at 0x0000013B56A3DDC0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56A22370> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B56A55850> False
# <keras.layers.core.activation.Activation object at 0x0000013B56A44E50> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B4A7520D0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B56A22580> False
# <keras.layers.merging.add.Add object at 0x0000013B4A79AD60> False
# <keras.layers.core.activation.Activation object at 0x0000013B56A3D790> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56A224C0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B10EB6130> False
# <keras.layers.core.activation.Activation object at 0x0000013B776553A0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56A7DCA0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B5609D0A0> False
# <keras.layers.core.activation.Activation object at 0x0000013B56A94E20> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56A9BFA0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56A86AF0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B56A9BFD0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B56AA3F40> False
# <keras.layers.merging.add.Add object at 0x0000013B56A86910> False
# <keras.layers.core.activation.Activation object at 0x0000013B4A6BF370> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56A9BC70> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B56A86850> False
# <keras.layers.core.activation.Activation object at 0x0000013B560C0880> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56A6F550> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B63385220> False
# <keras.layers.core.activation.Activation object at 0x0000013B56A1BAF0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56ABE040> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B56A355E0> False
# <keras.layers.merging.add.Add object at 0x0000013B6377B5B0> False
# <keras.layers.core.activation.Activation object at 0x0000013B637734C0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B63781E20> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B637606A0> False
# <keras.layers.core.activation.Activation object at 0x0000013B63760BB0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56ABE0D0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B6377B7C0> False
# <keras.layers.core.activation.Activation object at 0x0000013B63754AC0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000013B56AC5CD0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000013B56ABEEB0> False
# <keras.layers.merging.add.Add object at 0x0000013B56A22340> False
# <keras.layers.core.activation.Activation object at 0x0000013B63760700> False
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x0000013B56A61670> False
# <keras.layers.reshaping.flatten.Flatten object at 0x0000013B35966FD0> True
# <keras.layers.core.dense.Dense object at 0x0000013B63788970> True
# <keras.layers.core.dense.Dense object at 0x0000013B63787D60> True
# <keras.layers.core.dense.Dense object at 0x0000013B560C0220> True

# %%
model.compile(loss="categorical_crossentropy", optimizer='adam',metrics=["accuracy"])

# %%
history=model.fit(
    X_train,y_train,
    epochs=100,
    batch_size=100,
    validation_data=(X_test,y_test)
    )
# Out:
# Epoch 1/100
# 252/252 [==============================] - 341s 1s/step - loss: 1.0966 - accuracy: 0.6880 - val_loss: 0.7970 - val_accuracy: 0.7300
# Epoch 2/100
# 252/252 [==============================] - 354s 1s/step - loss: 0.5148 - accuracy: 0.8263 - val_loss: 0.7282 - val_accuracy: 0.7691
# Epoch 3/100
# 252/252 [==============================] - 339s 1s/step - loss: 0.3684 - accuracy: 0.8753 - val_loss: 0.7429 - val_accuracy: 0.7672
# Epoch 4/100
# 252/252 [==============================] - 343s 1s/step - loss: 0.2341 - accuracy: 0.9194 - val_loss: 0.7593 - val_accuracy: 0.7834
# Epoch 5/100
# 252/252 [==============================] - 360s 1s/step - loss: 0.1540 - accuracy: 0.9494 - val_loss: 0.8781 - val_accuracy: 0.7786
# Epoch 6/100
# 252/252 [==============================] - 377s 1s/step - loss: 0.1183 - accuracy: 0.9598 - val_loss: 1.0127 - val_accuracy: 0.7786
# Epoch 7/100
# 252/252 [==============================] - 369s 1s/step - loss: 0.0981 - accuracy: 0.9673 - val_loss: 1.0396 - val_accuracy: 0.7643
# Epoch 8/100
# 252/252 [==============================] - 369s 1s/step - loss: 0.1013 - accuracy: 0.9653 - val_loss: 1.1096 - val_accuracy: 0.7729
# Epoch 9/100
# 252/252 [==============================] - 368s 1s/step - loss: 0.1031 - accuracy: 0.9647 - val_loss: 1.4366 - val_accuracy: 0.7500
# Epoch 10/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.1157 - accuracy: 0.9596 - val_loss: 1.2856 - val_accuracy: 0.7691
# Epoch 11/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0929 - accuracy: 0.9676 - val_loss: 1.3289 - val_accuracy: 0.7662
# Epoch 12/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0544 - accuracy: 0.9811 - val_loss: 1.3297 - val_accuracy: 0.7643
# Epoch 13/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0566 - accuracy: 0.9805 - val_loss: 1.4323 - val_accuracy: 0.7653
# Epoch 14/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0722 - accuracy: 0.9765 - val_loss: 1.7574 - val_accuracy: 0.7557
# Epoch 15/100
# 252/252 [==============================] - 378s 2s/step - loss: 0.0696 - accuracy: 0.9766 - val_loss: 1.5740 - val_accuracy: 0.7691
# Epoch 16/100
# 252/252 [==============================] - 390s 2s/step - loss: 0.0628 - accuracy: 0.9790 - val_loss: 1.5214 - val_accuracy: 0.7672
# Epoch 17/100
# 252/252 [==============================] - 414s 2s/step - loss: 0.0494 - accuracy: 0.9839 - val_loss: 1.6379 - val_accuracy: 0.7500
# Epoch 18/100
# 252/252 [==============================] - 403s 2s/step - loss: 0.0559 - accuracy: 0.9816 - val_loss: 1.5801 - val_accuracy: 0.7691
# Epoch 19/100
# 252/252 [==============================] - 378s 1s/step - loss: 0.0425 - accuracy: 0.9853 - val_loss: 1.6778 - val_accuracy: 0.7672
# Epoch 20/100
# 252/252 [==============================] - 377s 1s/step - loss: 0.0535 - accuracy: 0.9820 - val_loss: 1.6738 - val_accuracy: 0.7653
# Epoch 21/100
# 252/252 [==============================] - 375s 1s/step - loss: 0.0770 - accuracy: 0.9746 - val_loss: 1.8868 - val_accuracy: 0.7634
# Epoch 22/100
# 252/252 [==============================] - 377s 1s/step - loss: 0.0681 - accuracy: 0.9778 - val_loss: 1.7797 - val_accuracy: 0.7815
# Epoch 23/100
# 252/252 [==============================] - 376s 1s/step - loss: 0.0322 - accuracy: 0.9894 - val_loss: 1.8648 - val_accuracy: 0.7767
# Epoch 24/100
# 252/252 [==============================] - 374s 1s/step - loss: 0.0477 - accuracy: 0.9855 - val_loss: 1.9010 - val_accuracy: 0.7576
# Epoch 25/100
# 252/252 [==============================] - 374s 1s/step - loss: 0.0472 - accuracy: 0.9837 - val_loss: 1.8511 - val_accuracy: 0.7748
# Epoch 26/100
# 252/252 [==============================] - 368s 1s/step - loss: 0.0341 - accuracy: 0.9890 - val_loss: 1.8595 - val_accuracy: 0.7691
# Epoch 27/100
# 252/252 [==============================] - 373s 1s/step - loss: 0.0421 - accuracy: 0.9858 - val_loss: 1.9417 - val_accuracy: 0.7643
# Epoch 28/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0488 - accuracy: 0.9847 - val_loss: 2.1392 - val_accuracy: 0.7700
# Epoch 29/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0458 - accuracy: 0.9854 - val_loss: 1.9307 - val_accuracy: 0.7882
# Epoch 30/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0467 - accuracy: 0.9848 - val_loss: 1.7648 - val_accuracy: 0.7844
# Epoch 31/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0280 - accuracy: 0.9907 - val_loss: 2.1172 - val_accuracy: 0.7748
# Epoch 32/100
# 252/252 [==============================] - 373s 1s/step - loss: 0.0344 - accuracy: 0.9892 - val_loss: 1.8810 - val_accuracy: 0.7834
# Epoch 33/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0364 - accuracy: 0.9878 - val_loss: 2.0628 - val_accuracy: 0.7710
# Epoch 34/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0210 - accuracy: 0.9932 - val_loss: 2.0474 - val_accuracy: 0.7834
# Epoch 35/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0356 - accuracy: 0.9886 - val_loss: 2.3609 - val_accuracy: 0.7586
# Epoch 36/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0582 - accuracy: 0.9819 - val_loss: 2.0374 - val_accuracy: 0.7815
# Epoch 37/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0418 - accuracy: 0.9871 - val_loss: 2.2729 - val_accuracy: 0.7796
# Epoch 38/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0343 - accuracy: 0.9899 - val_loss: 2.2510 - val_accuracy: 0.7729
# Epoch 39/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0291 - accuracy: 0.9908 - val_loss: 2.2163 - val_accuracy: 0.7824
# Epoch 40/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0272 - accuracy: 0.9913 - val_loss: 2.3115 - val_accuracy: 0.7700
# Epoch 41/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0269 - accuracy: 0.9914 - val_loss: 2.1825 - val_accuracy: 0.7758
# Epoch 42/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 2.1089 - val_accuracy: 0.7815
# Epoch 43/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0360 - accuracy: 0.9890 - val_loss: 2.1873 - val_accuracy: 0.7719
# Epoch 44/100
# 252/252 [==============================] - 368s 1s/step - loss: 0.0360 - accuracy: 0.9886 - val_loss: 2.1757 - val_accuracy: 0.7824
# Epoch 45/100
# 252/252 [==============================] - 368s 1s/step - loss: 0.0312 - accuracy: 0.9902 - val_loss: 2.6645 - val_accuracy: 0.7662
# Epoch 46/100
# 252/252 [==============================] - 369s 1s/step - loss: 0.0364 - accuracy: 0.9884 - val_loss: 2.1307 - val_accuracy: 0.7968
# Epoch 47/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 2.3118 - val_accuracy: 0.7815
# Epoch 48/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0264 - accuracy: 0.9916 - val_loss: 2.1541 - val_accuracy: 0.7691
# Epoch 49/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 2.2070 - val_accuracy: 0.7996
# Epoch 50/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0245 - accuracy: 0.9926 - val_loss: 2.2599 - val_accuracy: 0.7796
# Epoch 51/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0384 - accuracy: 0.9887 - val_loss: 2.4589 - val_accuracy: 0.7624
# Epoch 52/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0200 - accuracy: 0.9945 - val_loss: 2.3691 - val_accuracy: 0.7605
# Epoch 53/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 2.5397 - val_accuracy: 0.7595
# Epoch 54/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0294 - accuracy: 0.9914 - val_loss: 2.4913 - val_accuracy: 0.7748
# Epoch 55/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0426 - accuracy: 0.9879 - val_loss: 2.6146 - val_accuracy: 0.7824
# Epoch 56/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0311 - accuracy: 0.9901 - val_loss: 2.2922 - val_accuracy: 0.7691
# Epoch 57/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0123 - accuracy: 0.9955 - val_loss: 2.3444 - val_accuracy: 0.7815
# Epoch 58/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 2.3980 - val_accuracy: 0.7805
# Epoch 59/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 2.5562 - val_accuracy: 0.7624
# Epoch 60/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0217 - accuracy: 0.9933 - val_loss: 2.3119 - val_accuracy: 0.7872
# Epoch 61/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0449 - accuracy: 0.9867 - val_loss: 2.4734 - val_accuracy: 0.7643
# Epoch 62/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0216 - accuracy: 0.9934 - val_loss: 2.2746 - val_accuracy: 0.7710
# Epoch 63/100
# 252/252 [==============================] - 368s 1s/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 2.4791 - val_accuracy: 0.7777
# Epoch 64/100
# 252/252 [==============================] - 368s 1s/step - loss: 0.0187 - accuracy: 0.9945 - val_loss: 2.7294 - val_accuracy: 0.7691
# Epoch 65/100
# 252/252 [==============================] - 368s 1s/step - loss: 0.0227 - accuracy: 0.9936 - val_loss: 2.5965 - val_accuracy: 0.7681
# Epoch 66/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 2.3881 - val_accuracy: 0.7767
# Epoch 67/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 2.4045 - val_accuracy: 0.7691
# Epoch 68/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0260 - accuracy: 0.9928 - val_loss: 2.5482 - val_accuracy: 0.7824
# Epoch 69/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0171 - accuracy: 0.9949 - val_loss: 2.6186 - val_accuracy: 0.7777
# Epoch 70/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0324 - accuracy: 0.9906 - val_loss: 2.3066 - val_accuracy: 0.7767
# Epoch 71/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0141 - accuracy: 0.9954 - val_loss: 2.5056 - val_accuracy: 0.7805
# Epoch 72/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 2.3319 - val_accuracy: 0.7844
# Epoch 73/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0213 - accuracy: 0.9938 - val_loss: 2.4291 - val_accuracy: 0.7853
# Epoch 74/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0170 - accuracy: 0.9947 - val_loss: 2.5281 - val_accuracy: 0.7872
# Epoch 75/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0172 - accuracy: 0.9951 - val_loss: 2.5127 - val_accuracy: 0.7815
# Epoch 76/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0223 - accuracy: 0.9938 - val_loss: 2.3365 - val_accuracy: 0.7815
# Epoch 77/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 2.4129 - val_accuracy: 0.7824
# Epoch 78/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0212 - accuracy: 0.9935 - val_loss: 2.7571 - val_accuracy: 0.7615
# Epoch 79/100
# 252/252 [==============================] - 370s 1s/step - loss: 0.0276 - accuracy: 0.9920 - val_loss: 2.6700 - val_accuracy: 0.7719
# Epoch 80/100
# 252/252 [==============================] - 371s 1s/step - loss: 0.0224 - accuracy: 0.9936 - val_loss: 3.1442 - val_accuracy: 0.7615
# Epoch 81/100
# 252/252 [==============================] - 353s 1s/step - loss: 0.0211 - accuracy: 0.9942 - val_loss: 2.9466 - val_accuracy: 0.7691
# Epoch 82/100
# 252/252 [==============================] - 328s 1s/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 2.6423 - val_accuracy: 0.7719
# Epoch 83/100
# 252/252 [==============================] - 320s 1s/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 2.6047 - val_accuracy: 0.7729
# Epoch 84/100
# 252/252 [==============================] - 317s 1s/step - loss: 0.0263 - accuracy: 0.9928 - val_loss: 2.9229 - val_accuracy: 0.7710
# Epoch 85/100
# 252/252 [==============================] - 317s 1s/step - loss: 0.0163 - accuracy: 0.9955 - val_loss: 2.7633 - val_accuracy: 0.7767
# Epoch 86/100
# 252/252 [==============================] - 329s 1s/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 2.6463 - val_accuracy: 0.7834
# Epoch 87/100
# 252/252 [==============================] - 330s 1s/step - loss: 0.0137 - accuracy: 0.9960 - val_loss: 2.8207 - val_accuracy: 0.7844
# Epoch 88/100
# 252/252 [==============================] - 330s 1s/step - loss: 0.0352 - accuracy: 0.9905 - val_loss: 2.5495 - val_accuracy: 0.7824
# Epoch 89/100
# 252/252 [==============================] - 327s 1s/step - loss: 0.0208 - accuracy: 0.9935 - val_loss: 2.4741 - val_accuracy: 0.7700
# Epoch 90/100
# 252/252 [==============================] - 328s 1s/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 2.5834 - val_accuracy: 0.7729
# Epoch 91/100
# 252/252 [==============================] - 329s 1s/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 2.8346 - val_accuracy: 0.7748
# Epoch 92/100
# 252/252 [==============================] - 327s 1s/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 2.8602 - val_accuracy: 0.7672
# Epoch 93/100
# 252/252 [==============================] - 330s 1s/step - loss: 0.0167 - accuracy: 0.9957 - val_loss: 2.8521 - val_accuracy: 0.7576
# Epoch 94/100
# 252/252 [==============================] - 328s 1s/step - loss: 0.0391 - accuracy: 0.9908 - val_loss: 2.7090 - val_accuracy: 0.7853
# Epoch 95/100
# 252/252 [==============================] - 330s 1s/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 2.6485 - val_accuracy: 0.7805
# Epoch 96/100
# 252/252 [==============================] - 328s 1s/step - loss: 0.0180 - accuracy: 0.9952 - val_loss: 2.5920 - val_accuracy: 0.7719
# Epoch 97/100
# 252/252 [==============================] - 330s 1s/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 2.6060 - val_accuracy: 0.7815
# Epoch 98/100
# 252/252 [==============================] - 330s 1s/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 2.7247 - val_accuracy: 0.7844
# Epoch 99/100
# 252/252 [==============================] - 329s 1s/step - loss: 0.0080 - accuracy: 0.9979 - val_loss: 2.5786 - val_accuracy: 0.7796
# Epoch 100/100
# 252/252 [==============================] - 328s 1s/step - loss: 0.0216 - accuracy: 0.9938 - val_loss: 2.7997 - val_accuracy: 0.7786

# %%
from sklearn.metrics import confusion_matrix

y_pred=model.predict(X_test)
y_pred_one_hot=np.argmax(y_pred,axis=1)
y_test_one_hot=np.argmax(y_test,axis=1)
confusion_mat=confusion_matrix(y_test_one_hot, y_pred_one_hot)
print(confusion_mat)
# Out:
# 33/33 [==============================] - 16s 456ms/step
# [[143   6   4   0   4  11   4   5   6   4]
#  [ 11  94   4   0   4   3   3   1   2   3]
#  [  1   1  58   0   2   0   2   0   1   1]
#  [  1   0   0  62   5   2   0   0  13   0]
#  [  6   0   0   2  91   1   0   2   8   2]
#  [ 11   0   0   0   1  52   1   0   2   4]
#  [  2   8   3   0   1   0  37   6   1   0]
#  [  6   2   9   0   3   4   5  46   1   0]
#  [  1   0   0   4   3   0   1   0 178   0]
#  [  7   1   1   0   5   7   0   0   7  55]]

# %%
report= classification_report(y_test_one_hot,y_pred_one_hot)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76       187
#            1       0.84      0.75      0.79       125
#            2       0.73      0.88      0.80        66
#            3       0.91      0.75      0.82        83
#            4       0.76      0.81      0.79       112
#            5       0.65      0.73      0.69        71
#            6       0.70      0.64      0.67        58
#            7       0.77      0.61      0.68        76
#            8       0.81      0.95      0.88       187
#            9       0.80      0.66      0.72        83
#
#     accuracy                           0.78      1048
#    macro avg       0.77      0.75      0.76      1048
# weighted avg       0.78      0.78      0.78      1048

# %%
import matplotlib.pyplot as plt                                                   #Mengimpor modul matplotlib
acc = history.history['accuracy']                                                 #Nilai akurasi training
val_acc = history.history['val_accuracy']                                         #Nilai akurasi validasi
loss = history.history['loss']                                                    #Nilai loss training
val_loss = history.history['val_loss']                                            #Nilai loss validasi

epochs = range(len(acc))                                                          #Jumlah epoch

plt.plot(epochs, acc, 'r', label='Akurasi Training ')                             #Plot nilai akurasi training                     
plt.plot(epochs, val_acc, 'b', label='Akurasi Validasi')                          #Plot nilai akurasi validasi
plt.title('Akurasi Training dan Validasi')                                        #Menamai gambar
plt.legend(loc=0)                                                                 #Menampilkan legenda
plt.figure()                                                                      
plt.show()
